# %% [markdown]
# # Preprocessing
# Here we clean the data and handle missing values.

# %%
import pandas as pd
import sys
sys.path.append('..')
from src.preprocessing import load_data, clean_data, scale_features

# %%
raw_data_path = '../dataset/raw_data/sports_data.csv'
df = load_data(raw_data_path)
df_clean = clean_data(df)
df_clean.info()

# %%
df_clean.to_csv('../dataset/processed_data/cleaned_sports_data.csv', index=False)
print('Cleaned data saved.')
