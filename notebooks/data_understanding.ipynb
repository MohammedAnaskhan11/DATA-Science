# %% [markdown]
# # Data Understanding
# In this notebook, we load the raw dataset and explore its basic structure.

# %%
import pandas as pd
import sys
sys.path.append('..')
from src.preprocessing import load_data

# %%
raw_data_path = '../dataset/raw_data/sports_data.csv'
df = load_data(raw_data_path)
df.head()

# %%
df.info()

# %%
df.describe()
