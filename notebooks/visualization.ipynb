# %% [markdown]
# # Visualization and EDA
# Generating plots to understand feature relationships.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('..')
from src.analysis import perform_eda

# %%
df = pd.read_csv('../dataset/processed_data/cleaned_sports_data.csv')
perform_eda(df, output_dir='../outputs/graphs')

# %%
from IPython.display import Image
Image(filename='../outputs/graphs/correlation_heatmap.png')
